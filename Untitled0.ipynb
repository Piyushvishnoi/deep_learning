# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyushvishnoi/deep_learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/deep_learning
# Out:
# /content/drive/MyDrive/deep_learning

# %%
ls
# Out:
#  archive.zip
#  dataset/
#  Dog_breed_classification_model/
# 'dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh'

# %%
#import os
#os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/deep_learning"

# %%
#ls
# Out:
# archive.zip  dataset/

# %%
# %cd /content/drive/MyDrive/deep_learning/dataset/
# Out:
# /content/drive/MyDrive/deep_learning/dataset

# %%
ls
# Out:
# 'Affenhuahua dog'/       'Auggie dog'/            'Borzoi dog'/
# 'Afgan Hound dog'/       'Beagle dog'/            'Boxer dog'/
# 'Akita dog'/             'Belgian Tervuren dog'/  'Bugg dog'/
# 'Alaskan Malamute dog'/  'Bichon Frise dog'/      'Bulldog dog'/
# 'American Bulldog dog'/  'Bocker dog'/

# %%
cd ..
# Out:
# /content/drive/MyDrive/deep_learning

# %%
import os

for root, dirs, files in os.walk("dataset"):
    print(f"There are {len(files)} files in {root}")
# Out:
# There are 0 files in dataset
# There are 50 files in dataset/Affenhuahua dog
# There are 50 files in dataset/Afgan Hound dog
# There are 49 files in dataset/Akita dog
# There are 50 files in dataset/Alaskan Malamute dog
# There are 48 files in dataset/American Bulldog dog
# There are 50 files in dataset/Auggie dog
# There are 50 files in dataset/Beagle dog
# There are 50 files in dataset/Belgian Tervuren dog
# There are 50 files in dataset/Bichon Frise dog
# There are 50 files in dataset/Bocker dog
# There are 50 files in dataset/Borzoi dog
# There are 50 files in dataset/Boxer dog
# There are 50 files in dataset/Bugg dog
# There are 51 files in dataset/Bulldog dog

# %%
import numpy as np
class_names = np.array(sorted(os.listdir('/content/drive/MyDrive/deep_learning/dataset')))
class_names
# Out:
# array(['Affenhuahua dog', 'Afgan Hound dog', 'Akita dog',
#        'Alaskan Malamute dog', 'American Bulldog dog', 'Auggie dog',
#        'Beagle dog', 'Belgian Tervuren dog', 'Bichon Frise dog',
#        'Bocker dog', 'Borzoi dog', 'Boxer dog', 'Bugg dog', 'Bulldog dog'],
#       dtype='<U20')

# %%
import random
import matplotlib.pyplot as plt




def random_images():
    random_classname = random.choice(class_names)
    p = random_classname
    plt.figure(figsize=(10,10))

    path = "/content/drive/MyDrive/deep_learning/dataset"
    inner_path = path+"/"+p
    files = os.listdir(inner_path)
    d = random.choice(files)
    image_path = inner_path+"/"+d
    print(image_path)

    image = plt.imread(image_path)
    plt.imshow(image)
    plt.axis(False)

    print(image.shape)
    print("Max: ", image.max())
    print("Min: ", image.min())


random_images()
# Out:
# /content/drive/MyDrive/deep_learning/dataset/Borzoi dog/Image_13.jpg
# (1024, 629, 3)
# Max:  255
# Min:  0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.random.set_seed(42)

dir = "/content/drive/MyDrive/deep_learning/dataset"

datagen = ImageDataGenerator(rescale=1/255.,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             shear_range=0.2,
                             rotation_range=20,
                             horizontal_flip = True)

data = datagen.flow_from_directory(directory=  dir,
                                   target_size= (512, 512),
                                   class_mode= 'categorical',
                                   batch_size= 32,
                                   shuffle= True,)
# Out:
# Found 695 images belonging to 14 classes.

# %%
images, labels = data.next()
random_number = random.sample(range(len(images)), 1)[0]
plt.imshow(images[random_number])
plt.title(class_names[np.argmax(labels[random_number])])
plt.axis(False);

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential

# %%
# base_model = tf.keras.applications.EfficientNetB0(include_top=False)
# base_model.trainable=False

# # Setup model architecture with trainable top layers
# inputs = layers.Input(shape=(512,512,3), name="input_layer")
# x = base_model(inputs, training=False) #Put the base model in inference mode, and so weights ehich remains frozen, remains frozen
# x = layers.GlobalAveragePooling2D(name="global_average_pool_layer")(x)
# outputs = layers.Dense(len(class_names), activation="sigmoid", name="output_layer")(x)
# model = tf.keras.Model(inputs, outputs)
# Out:
# ...
# 16719872/16705208 [==============================] - 1s 0us/step

# %%
#model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (InputLayer)     [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
# _________________________________________________________________
# global_average_pool_layer (G (None, 1280)              0
# _________________________________________________________________
# output_layer (Dense)         (None, 14)                17934
# ...
# Total params: 4,067,505
# Trainable params: 17,934
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
# base_model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, None, None, 3 7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, None, None, 3 0           normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# # Compile 
# model.compile(loss="categorical_crossentropy",
#               optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#               metrics=["accuracy"])

# # Fit
# history = model.fit(data,
#                     epochs=10,
#                     steps_per_epoch=len(data))
# Out:
# Epoch 1/10
# 22/22 [==============================] - 427s 18s/step - loss: 2.6470 - accuracy: 0.0692
# Epoch 2/10
# 22/22 [==============================] - 53s 2s/step - loss: 2.6425 - accuracy: 0.0720
# Epoch 3/10
# 22/22 [==============================] - 53s 2s/step - loss: 2.6416 - accuracy: 0.0720
# Epoch 4/10
# 22/22 [==============================] - 53s 2s/step - loss: 2.6411 - accuracy: 0.0692
# Epoch 5/10
# 22/22 [==============================] - 53s 2s/step - loss: 2.6401 - accuracy: 0.0548
# Epoch 6/10
# 22/22 [==============================] - 53s 2s/step - loss: 2.6405 - accuracy: 0.0620
# Epoch 7/10
# 22/22 [==============================] - 54s 2s/step - loss: 2.6408 - accuracy: 0.0720
# Epoch 8/10
# 22/22 [==============================] - 54s 2s/step - loss: 2.6404 - accuracy: 0.0720
# Epoch 9/10
# 22/22 [==============================] - 54s 2s/step - loss: 2.6407 - accuracy: 0.0504
# Epoch 10/10
# ...

# %%
# model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (InputLayer)     [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
# _________________________________________________________________
# global_average_pool_layer (G (None, 1280)              0
# _________________________________________________________________
# output_layer (Dense)         (None, 14)                17934
# ...
# Total params: 4,067,505
# Trainable params: 17,934
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
base_model_2 =  tf.keras.applications.InceptionResNetV2(
    include_top = False, 
    weights = 'imagenet', 
    input_tensor = None,
    input_shape = (512, 512, 3), 
    pooling = None, 
    classes = 1000
)
# Out:
# ...
# 219070464/219055592 [==============================] - 3s 0us/step

# %%
base_model_2.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 255, 255, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 255, 255, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 255, 255, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
base_model_2.trainable=False

# %%
# Setup model architecture with trainable top layers
inputs = layers.Input(shape=(512,512,3), name="input_layer")
x = base_model_2(inputs, training=False) #Put the base model in inference mode, and so weights ehich remains frozen, remains frozen
x = layers.Conv2D(64, (3, 3), activation = 'relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(len(class_names), activation="softmax", name="output_layer")(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.00009), 
              metrics = ["accuracy"])

# %%
# Fit
history = model.fit(data,
                    epochs=15,
                    steps_per_epoch=len(data))
# Out:
# Epoch 1/15
# 22/22 [==============================] - 206s 7s/step - loss: 2.5921 - accuracy: 0.1410
# Epoch 2/15
# 22/22 [==============================] - 66s 3s/step - loss: 2.1943 - accuracy: 0.3281
# Epoch 3/15
# 22/22 [==============================] - 66s 3s/step - loss: 1.7931 - accuracy: 0.4590
# Epoch 4/15
# 22/22 [==============================] - 65s 3s/step - loss: 1.4682 - accuracy: 0.5626
# Epoch 5/15
# 22/22 [==============================] - 65s 3s/step - loss: 1.3227 - accuracy: 0.6101
# Epoch 6/15
# 22/22 [==============================] - 67s 3s/step - loss: 1.0853 - accuracy: 0.6878
# Epoch 7/15
# 22/22 [==============================] - 67s 3s/step - loss: 0.9693 - accuracy: 0.7151
# Epoch 8/15
# 22/22 [==============================] - 66s 3s/step - loss: 0.8412 - accuracy: 0.7698
# Epoch 9/15
# 22/22 [==============================] - 66s 3s/step - loss: 0.7613 - accuracy: 0.7914
# Epoch 10/15
# ...

# %%
model.evaluate(data)
# Out:
# 22/22 [==============================] - 69s 3s/step - loss: 0.3845 - accuracy: 0.8964
# [0.3845176696777344, 0.896402895450592]

# %%
model.save("Dog_breed_classification_model")
# Out:
# INFO:tensorflow:Assets written to: Dog_breed_classification_model/assets

# %%
ls
# Out:
# archive.zip  dataset/  Dog_breed_classification_model/

# %%
pwd
# Out:
# '/content/drive/My Drive/deep_learning'

# %%
ls
# Out:
# archive.zip  dataset/  Dog_breed_classification_model/

# %%
import tensorflow as tf

# %%
cd /content
# Out:
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
model = tf.keras.models.load_model("/content/drive/MyDrive/deep_learning/Dog_breed_classification_model")

# %%
def load_and_prep_image(filename, img_shape=512, scale=True):

  img = tf.io.read_file(filename)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.resize(img, [img_shape, img_shape])
  if scale:
    return img/255.
  else:
    return img

# %%
import matplotlib.pyplot as plt

def pred_and_plot(model, filename, class_names):

  img = load_and_prep_image(filename)
  pred = model.predict(tf.expand_dims(img, axis=0))

  if len(pred[0]) > 1: 
    pred_class = class_names[pred.argmax()]
  else:
    pred_class = class_names[int(tf.round(pred)[0][0])]

  plt.imshow(img)
  plt.title(f"Prediction: {pred_class} \nProbability: {pred.max()*100:.3f}%")
  plt.axis(False);

# %%
ls
# Out:
# drive/  sample_data/

# %%
pwd
# Out:
# '/content'

# %%
pred_and_plot(model = model, 
              filename = "/content/drive/MyDrive/deep_learning/dataset/Auggie dog/Image_12.JPG", 
              class_names = class_names)

# %%
cd /content/drive/MyDrive/deep_learning
# Out:
# /content/drive/MyDrive/deep_learning

# %%
pwd
# Out:
# '/content/drive/MyDrive/deep_learning'

# %%
# !wget https://drive.google.com/drive/u/0/folders/19m7ILXg073guq251qB0D9wGewiN-55wJ/image.jpg
# Out:
# --2021-10-11 16:25:14--  https://drive.google.com/drive/u/0/folders/19m7ILXg073guq251qB0D9wGewiN-55wJ/image.jpg
# Resolving drive.google.com (drive.google.com)... 142.251.6.139, 142.251.6.138, 142.251.6.102, ...
# Connecting to drive.google.com (drive.google.com)|142.251.6.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://drive.google.com/drive/folders/19m7ILXg073guq251qB0D9wGewiN-55wJ/image.jpg [following]
# --2021-10-11 16:25:14--  https://drive.google.com/drive/folders/19m7ILXg073guq251qB0D9wGewiN-55wJ/image.jpg
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 400 Bad Request
# 2021-10-11 16:25:14 ERROR 400: Bad Request.

# %%
ls
# Out:
# archive.zip  dataset/  Dog_breed_classification_model/

# %%
# !wget https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh;0,0.190xh&resize=1200:*
# Out:
# --2021-10-11 16:27:10--  https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh
# Resolving hips.hearstapps.com (hips.hearstapps.com)... 151.101.0.155, 151.101.64.155, 151.101.128.155, ...
# Connecting to hips.hearstapps.com (hips.hearstapps.com)|151.101.0.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101744 (99K) [image/jpeg]
# Saving to: ‘dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh’
#
# dog-puppy-on-garden 100%[===================>]  99.36K  --.-KB/s    in 0.02s
#
# 2021-10-11 16:27:11 (6.01 MB/s) - ‘dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh’ saved [101744/101744]
#
# /bin/bash: 0,0.190xh: command not found

# %%
# %ls
# Out:
#  archive.zip
#  dataset/
#  Dog_breed_classification_model/
# 'dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh'

# %%
pred_and_plot(model = model, 
              filename = "/content/drive/MyDrive/deep_learning/dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh", 
              class_names = class_names)

# %%
ls
# Out:
#  archive.zip
#  dataset/
#  Dog_breed_classification_model/
# 'dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=1.00xw:0.669xh'
